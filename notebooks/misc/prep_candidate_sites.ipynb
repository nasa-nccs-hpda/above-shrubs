# %% [markdown]
# # Prepare candidate sites for $CHM_{SR}$ change analysis
#
# #### multi-decadal vegetation structure change in the Arctic
# Candidate sites are those:
# 1. for which we want to assess shrub change
# 2. have t1 and t2 VHR imagery
#
# Paul Montesano
# Jordan Caraballo-Vega
# Matthew Macander
# Mark Carroll
# Glenn Tamkin
# Caleb Spradlin
#
# Repositories:
# https://github.com/nasa-nccs-hpda/above-shrubs.git
#
# `Main Components:`
#  - Demonstrate the `candidate site` selection, which should have a VHR time series
#
# `Motivations:`
#
#  - need to assess ability to quantify shrub change from VHR CHM time series
#
# `Notes:`
#
# | Author | Affiliation | Date
# | ---------------- | ---------------- | ----------------
# | Paul Montesano, PhD | Innovation Lab ; NASA Goddard Space Flight Center | April 2024

# %%
import os
import pandas as pd
import glob
import geopandas as gpd
import sys
sys.path.append('/home/pmontesa/code/evhr')
sys.path.append('/home/pmontesa/code/icesat2_boreal/lib')
import maplib_folium

import matplotlib.pyplot as plt


import requests
import ipywidgets
import IPython.display
import contextily as ctx

# %% [markdown]
# ### Function to select polys of a gdf with another

# %%
def gdf_selection(gdf1, gdf2):
    return gdf1[gdf1.geometry.apply(lambda x: any(x.intersects(y) for y in gdf2.geometry))]

# %% [markdown]
# # Demonstrate `candidate site` selection with VHR time series

# %% [markdown]
# ## Suggest `candidate sites` that will be used to select VHR to see if there is a time series
#
# We want to identify candidtate sites for studying multi-decadal vegetation structure change. These sites should have both `old` and `new` data to complete a multi-decadal time series.
#
# ##### Notes
#  - https://docs.google.com/document/d/17gaIal1czeee1b09FixWu0GKAWVvR2yodU9fmwKuGXE/edit
#  - https://github.com/nasa-nccs-hpda/above-shrubs/blob/00c895e5dc4da4c6ba4e1fab2b1b59bfabdc2376/notebooks/Subset_Latest_NGA_Footprints.ipynb
#  - JJ squares classified:  mmacande/srlite/ecotype_model/20240116_JJsquares_meco2

# %%
dir_prj_pmm = '/explore/nobackup/people/pmontesa/userfs02/projects/ilab/above_shrubs'

# %%
# most recent 
footprint_chm = '/explore/nobackup/projects/above/misc/ABoVE_Shrubs/chm/20231014_chm/dm_10m/footprints/footprints_chm_20231023_vhrmeta.gpkg'
footprint_chm = '/explore/nobackup/projects/above/misc/ABoVE_Shrubs/footprints/footprints_20231014_chm.gpkg' # footprint_predictions.ipynb

# %%
MAINDIR = '/explore/nobackup/projects/above/misc/ABoVE_Shrubs'

# %%
sibbork_sites = gpd.read_file('/explore/nobackup/people/pmontesa/userfs02/projects/above_tte/LC2021_cmip6/input/footprints_LCunmasked.gpkg').to_crs(4326)
jj_squares = gpd.read_file(f'{dir_prj_pmm}/data/arc/footprints_jjsquare_vhrdata.gpkg')
jj_squares['name'] = 'jj_'+jj_squares.index.astype(str).str.pad(4, fillchar='0')
candidate_site_cols = ['name','file','area_km2','area_ha','geometry']
candidate_sites = pd.concat([sibbork_sites[candidate_site_cols], jj_squares[candidate_site_cols]])

# %%
sibbork_sites.total_bounds
# Out:
# array([-166.02532596,   60.42331767, -113.06006406,   69.23227233])

# %%
candidate_sites.explore(column='name', tiles='http://services.arcgisonline.com/ArcGIS/rest/services/Canvas/World_Light_Gray_Base/MapServer/tile/{z}/{y}/{x}',attr=' ')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9df3d04fa4943e80863324e99f7e0ebb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend name&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;name&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;Creamer_823_1_49&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;TL_MM27_T1_1_11&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;ambler&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;brooks01&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#aec7e8&#x27;&gt;&lt;/span&gt;brooks02&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#aec7e8&#x27;&gt;&lt;/span&gt;brooks04&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#aec7e8&#x27;&gt;&lt;/span&gt;brooksb06&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#aec7e8&#x27;&gt;&lt;/span&gt;brooksb07&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff7f0e&#x27;&gt;&lt;/span&gt;brooksb08&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff7f0e&#x27;&gt;&lt;/span&gt;brooksc11&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff7f0e&#x27;&gt;&lt;/span&gt;brooksc12r&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff7f0e&#x27;&gt;&lt;/span&gt;brooksc13r&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ffbb78&#x27;&gt;&lt;/span&gt;brooksc14r&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ffbb78&#x27;&gt;&lt;/span&gt;brooksc15r&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ffbb78&#x27;&gt;&lt;/span&gt;brooksd16&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ffbb78&#x27;&gt;&lt;/span&gt;brooksd17&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#2ca02c&#x27;&gt;&lt;/span&gt;brookseitel01&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#2ca02c&#x27;&gt;&lt;/span&gt;brookseitel02&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#2ca02c&#x27;&gt;&lt;/span&gt;brookseitel03&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#98df8a&#x27;&gt;&lt;/span&gt;brooksfirth01&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#98df8a&#x27;&gt;&lt;/span&gt;brooksfirth02&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#98df8a&#x27;&gt;&lt;/span&gt;brooksfirth03&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#98df8a&#x27;&gt;&lt;/span&gt;brooksfirth04&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#d62728&#x27;&gt;&lt;/span&gt;eaglebrown01&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#d62728&#x27;&gt;&lt;/span&gt;eaglebrown02&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#d62728&#x27;&gt;&lt;/span&gt;eaglebrown03&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#d62728&#x27;&gt;&lt;/span&gt;jj_0000&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff9896&

# %%
candidate_sites.to_file(os.path.join(MAINDIR, 'footprints','footprints_candidate_sites.gpkg'), driver='GPKG')

# %%
candidate_sites[candidate_sites.name == 'jj_0011'].file.to_list()
# Out:
# ['WV02_20190705_M1BS_1030010094740A00-sr-02m-jj-square.tif']

# %% [markdown]
# ## Identify potential VHR to match with `candidate sites`

# %%
FOOT_DATE_STR_LIST = ['20240202', '20231027']
FOOT_DATE_STR_LIST = [ '20231027']
FOOT_DATE_STR = '20240202'

# %%
# VHR footprints geodataframe - selected from NGA dB by MJM
fig,axes = plt.subplots(1,2, sharey=True, figsize=(10,3))
for i, ax in enumerate(axes):
    vhr_gdf = gpd.read_file(os.path.join(MAINDIR, 'footprints', f'nga_footprint_{FOOT_DATE_STR_LIST[i]}_subset_ak_filtered.gpkg'))
    vhr_gdf['year'] = vhr_gdf['acq_year'].apply(str)

    VHR_COLS_LIST = ['geometry','catid','sensor','acq_year','acq_month','year','cloudcover','avsunazim','min_added_date', 'max_added_date']
    vhr_gdf = vhr_gdf[VHR_COLS_LIST]

    ax = vhr_gdf.cx[-178:-110,40:80].plot(ax=ax, color='red', alpha=0.1, figsize=(5,4))
    ctx.add_basemap(ax=ax, crs=4326, source = ctx.providers.Esri.WorldGrayCanvas, attribution=' ')
    ax.title.set_text(FOOT_DATE_STR_LIST[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 4
#       2 fig,axes = plt.subplots(1,2, sharey=True, figsize=(10,3))
#       3 for i, ax in enumerate(axes):
# ----> 4     vhr_gdf = gpd.read_file(os.path.join(MAINDIR, 'footprints', f'nga_footprint_{FOOT_DATE_STR_LIST[i]}_subset_ak_filtered.gpkg'))
#       5     vhr_gdf['year'] = vhr_gdf['acq_year'].apply(str)
#       7     VHR_COLS_LIST = ['geometry','catid','sensor','acq_year','acq_month','year','cloudcover','avsunazim','min_added_date', 'max_added_date']
#
# IndexError: list index out of range

# %%
# %%time
ax = vhr_gdf.cx[-178:-110,40:80].plot(color='red', alpha=0.1, figsize=(5,4))
ctx.add_basemap(ax=ax, crs=4326, source = ctx.providers.Esri.WorldGrayCanvas, attribution=' ')
# Out:
# CPU times: user 8.43 s, sys: 320 ms, total: 8.75 s
# Wall time: 7.03 s

# %% [markdown]
# ### Select all VHR at `candidate sites`

# %%
#vhr_gdf_selection = gpd.sjoin(vhr_gdf, candidate_sites, op='intersects', how='left').dropna(subset=['index_right'])
vhr_gdf_selection = gdf_selection(vhr_gdf, candidate_sites.to_crs(vhr_gdf.crs))
ax = vhr_gdf_selection.cx[-178:-110,40:80].plot(color='red', alpha=0.1, figsize=(5,4))
ctx.add_basemap(ax=ax, crs=4326, source = ctx.providers.Esri.WorldGrayCanvas, attribution=' ')
# Out:
# KeyboardInterrupt

# %%
YEAR_OLD_THRESH_OLD = 2009
YEAR_OLD_THRESH_NEW = 2017
MONTH_LIST = [7,8]
COLS_DROP_LIST = ['min_added_date', 'max_added_date']

# %%
vhr_ikonos_july_aug.head()
# Out:
#                                                 geometry  \
# 29665  MULTIPOLYGON (((-151.80821 59.59379, -151.7893...
# 29666  MULTIPOLYGON (((-157.64291 62.39537, -157.6050...
# 29667  MULTIPOLYGON (((-163.56064 64.85562, -163.5507...
# 29668  MULTIPOLYGON (((-162.66066 66.77429, -162.6494...
# 29669  MULTIPOLYGON (((-163.00956 64.32910, -162.9742...
#
#                               catid sensor  acq_year  acq_month  year  \
# 29665  2000070421111030000010021782   IK01      2000          7  2000
# 29666  2000070521460010000010021902   IK01      2000          7  2000
# 29667  2000070622201840000010022655   IK01      2000          7  2000
# 29668  2000070622205390000010022657   IK01      2000          7  2000
# 29669  2000070622211760000010022658   IK01      2000          7  2000
#
#        cloudcover  avsunazim
# 29665        0.12        NaN
# 29666        0.07        NaN
# 29667        0.00        NaN
# 29668        0.00        NaN
# 29669        0.00        NaN

# %%
vhr_ikonos_july_aug = vhr_gdf[(vhr_gdf.sensor == 'IK01') & ((vhr_gdf.acq_month == 7) | (vhr_gdf.acq_month == 8))].drop(COLS_DROP_LIST, axis=1)
vhr_ikonos_july_aug.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81dc045e48d74bf7855d2a4ccc8170f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81dc045e48d74bf7855d2a4ccc8170f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81dc045e48d74bf7855d2a4ccc8170f2 = L.map(
#                 &quot;map_81dc045e48d74bf7855d2a4ccc8170f2&quot;,
#                 {
#                     center: [60.69453985900006, -148.61981900799998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_81dc045e48d74bf7855d2a4ccc8170f2);
#
#
#
#
#
#             var tile_layer_ec39ff22aaafc8fb43bfd7e11129cdeb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_81dc045e48d74bf7855d2a4ccc8170f2);
#
#
#             map_81dc045e48d74bf7855d2a4ccc8170f2.fitBounds(
#                 [[49.99844291100004, -175.27349544499998], [71.39063680700008, -121.96614257099998]],
#                 {}
#             );
#
#
#         function geo_json_03d5c310270b61b2dec09f4133d3d8d4_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_03d5c310270b61b2dec09f4133d3d8d4_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_03d5c310270b61b2dec09f4133d3d8d4_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_03d5c310270b61b2dec09f4133d3d8d4_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_03d5c310270b61b2dec09f4133d3d8d4_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_03d5c310270b61b2dec09f4133d3d8d4.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_03d5c310270b61b2dec09f4133d3d8d4_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_03d5c310270b61b2dec09f4133d3d8d4 = L.geoJson(null, {
#                 onEachFeature: geo_json_03d5c310270b61b2dec09f4133d3d8d4_onEachFeature,
#
#                 style: geo_json_03d5c310270b61b2dec09f4133d3d8d4_styler,
#                 pointToLayer: geo_json_03d5c310270b61b2dec09f4133d3d8d4_pointToLayer
#         });
#
#         function geo_json_03d5c310270b61b2dec09f4133d3d8d4_add (data) {
#             geo_json_03d5c310270b61b2dec09f4133d3d8d4
#                 .addData(data)
#                 .addTo(map_81dc045e48d74bf7855d2a4ccc8170f2);
#         }
#             geo_json_03d5c310270b61b2dec09f4133d3d8d4_add({&quot;bbox&quot;: [-175.27349544499998, 49.99844291100004, -121.96614257099998, 71.39063680700008], &quot;features&quot;: [{&quot;bbox&quot;: [-151.80821270399997, 59.59147261100003, -151.55398101999998, 60.11662547700007], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-151.80821270399997, 59.59378559600003], [-151.78936648999996, 60.11662547700007], [-151.55398101999998, 60.11426363000004], [-151.57648874099996, 59.59147261100003], [-151.80821270399997, 59.59378559600003]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;id&quot;: &quot;29665&quot;, &quot;properties&quot;: {&quot;acq_month&quot;: 7, &quot;acq_year&quot;: 2000, &quot;avsunazim&quot;: null, &quot;catid&quot;: &quot;2000070421111030000010021782&quot;, &quot;cloudcover&quot

# %%
vhr_gdf[vhr_gdf.catid.isin(['2000060822004260000010004709', '2000060822003210000010004708'])].drop(COLS_DROP_LIST, axis=1).explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_efe6c0e28eadc8110a7533a31328521c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_efe6c0e28eadc8110a7533a31328521c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_efe6c0e28eadc8110a7533a31328521c = L.map(
#                 &quot;map_efe6c0e28eadc8110a7533a31328521c&quot;,
#                 {
#                     center: [64.88292053950008, -163.48475705599998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_efe6c0e28eadc8110a7533a31328521c);
#
#
#
#
#
#             var tile_layer_dbee2eca29171790c9a6aa0b0dab4336 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_efe6c0e28eadc8110a7533a31328521c);
#
#
#             map_efe6c0e28eadc8110a7533a31328521c.fitBounds(
#                 [[64.79511088700008, -163.62906301299998], [64.97073019200008, -163.34045109899998]],
#                 {}
#             );
#
#
#         function geo_json_a349abe458521d1f693a652b95300f7d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_a349abe458521d1f693a652b95300f7d_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_a349abe458521d1f693a652b95300f7d_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_a349abe458521d1f693a652b95300f7d_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_a349abe458521d1f693a652b95300f7d_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_a349abe458521d1f693a652b95300f7d.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_a349abe458521d1f693a652b95300f7d_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_a349abe458521d1f693a652b95300f7d = L.geoJson(null, {
#                 onEachFeature: geo_json_a349abe458521d1f693a652b95300f7d_onEachFeature,
#
#                 style: geo_json_a349abe458521d1f693a652b95300f7d_styler,
#                 pointToLayer: geo_json_a349abe458521d1f693a652b95300f7d_pointToLayer
#         });
#
#         function geo_json_a349abe458521d1f693a652b95300f7d_add (data) {
#             geo_json_a349abe458521d1f693a652b95300f7d
#                 .addData(data)
#                 .addTo(map_efe6c0e28eadc8110a7533a31328521c);
#         }
#             geo_json_a349abe458521d1f693a652b95300f7d_add({&quot;bbox&quot;: [-163.62906301299998, 64.79511088700008, -163.34045109899998, 64.97073019200008], &quot;features&quot;: [{&quot;bbox&quot;: [-163.62634678499998, 64.79511088700008, -163.34495290099997, 64.97073019200008], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-163.62634678499998, 64.79786280900004], [-163.61748615199997, 64.97073019200008], [-163.34495290099997, 64.96795666900005], [-163.35555845199997, 64.79511088700008], [-163.62634678499998, 64.79786280900004]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;id&quot;: &quot;29638&quot;, &quot;properties&quot;: {&quot;acq_month&quot;: 6, &quot;acq_year&quot;: 2000, &quot;avsunazim&quot;: null, &quot;catid&quot;: &quot;2000060822003210000010004708&quot;, &quot;cloudcover&quot

# %% [markdown]
# ### Use candidate sites to select old data ($VHR_{t1}$)

# %%
#vhr_gdf_selection_old = gpd.sjoin(vhr_gdf_selection[vhr_gdf_selection.acq_year < YEAR_OLD_THRESH_OLD].dropna(subset=['index_right']).drop(['index_right'], axis=1), candidate_sites, op='intersects', how='left')
vhr_gdf_selection_old = gdf_selection(vhr_gdf_selection[(vhr_gdf_selection.acq_year < YEAR_OLD_THRESH_OLD) & (vhr_gdf_selection.acq_month.isin(MONTH_LIST))], candidate_sites)

# %%
ax = vhr_gdf_selection_old.plot(column='sensor', cmap='inferno', alpha=0.9, figsize=(5,4), legend=True)
ctx.add_basemap(ax=ax, crs=4326, source = ctx.providers.Esri.WorldGrayCanvas, attribution=' ')

# %%
vhr_gdf_selection_old[vhr_gdf_selection_old.sensor == 'IK01'].shape
# Out:
# (16, 10)

# %% [markdown]
# ### Map all $VHR_{t1}$ at candidate sites

# %%
m = vhr_gdf_selection_old.drop(COLS_DROP_LIST, axis=1).explore(column='sensor', cmap='inferno', legend=True, tiles=maplib_folium.tiler_basemap_image, attr=' ', legend_kwds={'location': 'top left'})
candidate_sites.explore(color='red', m=m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_927e4fe4bb61d7fe468759a320b6f6ad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend sensor&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;sensor&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#000004&#x27;&gt;&lt;/span&gt;IK01&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#fcffa4&#x27;&gt;&lt;/span&gt;QB02&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_927e4fe4bb61d7fe468759a320b6f6ad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_927e4fe4bb61d7fe468759a320b6f6ad = L.map(
#                 &quot;map_927e4fe4bb61d7fe468759a320b6f6ad&quot;,
#                 {
#                     center: [63.807357329500036, -144.67670948149998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_927e4fe4bb61d7fe468759a320b6f6ad);
#
#
#
#
#
#             var tile_layer_4dbfdc8ce33c725757b74a1d14b13816 = L.tileLayer(
#                 &quot;https://services.arcgisonline.com/arcgis/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot; &quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_927e4fe4bb61d7fe468759a320b6f6ad);
#
#
#             map_927e4fe4bb61d7fe468759a320b6f6ad.fitBounds(
#                 [[57.58358673500004, -166.09578296299998], [70.03112792400003, -123.25763599999999]],
#                 {}
#             );
#
#
#         function geo_json_d22a6465b0dd3cc3e4b54930da82c8f9_styler(feature) {
#             switch(feature.id) {
#                 case &quot;29667&quot;: case &quot;29745&quot;: case &quot;29746&quot;: case &quot;29760&quot;: case &quot;29873&quot;: case &quot;29962&quot;: case &quot;29963&quot;: case &quot;29966&quot;: case &quot;29970&quot;: case &quot;29977&quot;: case &quot;29981&quot;: case &quot;30079&quot;: case &quot;30080&quot;: case &quot;30251&quot;: case &quot;30319&quot;: case &quot;30401&quot;:
#                     return {&quot;color&quot;: &quot;#000004&quot;, &quot;fillColor&quot;: &quot;#000004&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#fcffa4&quot;, &quot;fillColor&quo

# %%
# # Manually target a pre-2006 CATID with a selection string that you find by manually mousing over the footprints in the map above - no need for the memorize and copy the full CATID - just the last 8 digits!
# CATID_SELECTION_STR = "10025793"
# vhr_gdf_targetcatid = vhr_gdf[vhr_gdf['catid'].str.contains(CATID_SELECTION_STR)].drop(['min_added_date', 'max_added_date'], axis=1)
# CATID = vhr_gdf_targetcatid.catid.to_list()[0]
# vhr_gdf_targetcatid.iloc[0]

# %%
#vhr_gdf_selection_new = vhr_gdf_selection.dropna(subset=['bands_right'])[vhr_gdf_selection.columns.drop(list(vhr_gdf_selection.filter(regex='_right')))]

# %% [markdown]
# ### Use candidate sites to select new $VHR_{t2}$

# %%
#vhr_gdf_selection_new = gpd.sjoin(vhr_gdf_selection[vhr_gdf_selection.acq_year > YEAR_OLD_THRESH_NEW].dropna(subset=['index_right']).drop(['index_right'], axis=1), candidate_sites, op='intersects', how='left')
vhr_gdf_selection_new = gdf_selection(vhr_gdf_selection[(vhr_gdf_selection.acq_year > YEAR_OLD_THRESH_NEW) & (vhr_gdf_selection.acq_month.isin(MONTH_LIST)) ], candidate_sites)
ax = vhr_gdf_selection_new.plot(column='sensor', cmap='inferno', alpha=0.9, figsize=(5,4), legend=True)
ctx.add_basemap(ax=ax, crs=4326, source = ctx.providers.Esri.WorldGrayCanvas, attribution=' ')

# %%
vhr_gdf_selection_new.shape
# Out:
# (303, 10)

# %% [markdown]
# ### Map all $VHR_{t2}$ at candidate sites

# %%
m = vhr_gdf_selection_new.drop(COLS_DROP_LIST, axis=1).explore(column='sensor', cmap='inferno', legend=True, tiles=maplib_folium.tiler_basemap_image, attr=' ')
#m = vhr_gdf_targetcatid.explore(m=m, color='red')
candidate_sites.explore(color='red', m=m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18b38d1a3c1f94ef66e179d44ffa26c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend sensor&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;sensor&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#000004&#x27;&gt;&lt;/span&gt;GE01&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#bc3754&#x27;&gt;&lt;/span&gt;WV02&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#fcffa4&#x27;&gt;&lt;/span&gt;WV03&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18b38d1a3c1f94ef66e179d44ffa26c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_18b38d1a3c1f94ef66e179d44ffa26c5 = L.map(
#                 &quot;map_18b38d1a3c1f94ef66e179d44ffa26c5&quot;,
#                 {
#                     center: [62.62405225750007, -144.06990813949997],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_18b38d1a3c1f94ef66e179d44ffa26c5);
#
#
#
#
#
#             var tile_layer_beeba4f7b6b5148633513f12a1a61425 = L.tileLayer(
#                 &quot;https://services.arcgisonline.com/arcgis/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot; &quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_18b38d1a3c1f94ef66e179d44ffa26c5);
#
#
#             map_18b38d1a3c1f94ef66e179d44ffa26c5.fitBounds(
#                 [[55.71722072000006, -166.21002196899997], [69.53088379500008, -121.92979430999998]],
#                 {}
#             );
#
#
#         function geo_json_49b06818a8b6613c7e03bcb3edcad8f7_styler(feature) {
#             switch(feature.id) {
#                 case &quot;20247&quot;: case &quot;20287&quot;: case &quot;20339&quot;: case &quot;20381&quot;: case &quot;20394&quot;: case &quot;20416&quot;: case &quot;20422&quot;: case &quot;20484&quot;: case &quot;20513&quot;: case &quot;20538&quot;: case &quot;20550&quot;: case &quot;20560&quot;: case &quot;20563&quot;: case &quot;20642&quot;: case &quot;20692&quot;: case &quot;20724&quot;: case &quot;20884&quot;: case &quot;21218&quot;: case &quot;21237&quot;: case &quot;21330&quot;: case &quot;21400&quot;: case &quot;21409&quot;: case &quot;21454&quot;: case &qu

# %% [markdown]
# ### Find candidate sites that have $VHR_{t1}$ and $VHR_{t2}$

# %%
COLS_DROP = list(vhr_gdf_selection_new.filter(regex='_left')) + list(vhr_gdf_selection_new.filter(regex='_right'))

# %%
candidate_sites_t1 = gpd.sjoin(candidate_sites, vhr_gdf_selection_old.drop(COLS_DROP, axis=1), op='intersects', how='left').dropna(subset=['sensor'])
candidate_sites_t2 = gpd.sjoin(candidate_sites, vhr_gdf_selection_new.drop(COLS_DROP, axis=1), op='intersects', how='left').dropna(subset=['sensor'])
# Out:
# /panfs/ccds02/app/modules/jupyter/ilab/tensorflow-kernel/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3400: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /panfs/ccds02/app/modules/jupyter/ilab/tensorflow-kernel/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3400: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %% [markdown]
# ## Build final database of all t1 and t2 pairs for all candidate sites

# %%
candidate_sites_t1_t2 = gpd.sjoin(candidate_sites_t1.drop('index_right', axis=1), vhr_gdf_selection_new.drop(COLS_DROP, axis=1), op='intersects', how='left')
candidate_sites_t1_t2['year_delta'] = candidate_sites_t1_t2['acq_year_right'] - candidate_sites_t1_t2['acq_year_left']
# Out:
# /panfs/ccds02/app/modules/jupyter/ilab/tensorflow-kernel/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3400: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
candidate_sites_t1_t2.to_file(f'{dir_prj_pmm}/data/arc/candidate_sites_t1t2_db.gpkg', driver='GPKG', mode='w')

# %% [markdown]
# ## At a candidate site, map all t2 strips associated with a t1 `catid`
#
# **not sure if this is useful**

# %%
def rm_datetime_cols(gdf, type_str="datetime64[ns, UTC]"):
    return list(set(gdf.columns) - set(gdf.select_dtypes(include=type_str).columns))

# %%
cand_site_name = 'jj_0011'

# %%
cand_site = candidate_sites_t1_t2[candidate_sites_t1_t2.name == cand_site_name]
print(cand_site.shape)
print(set(cand_site.catid_left.to_list()))
# Out:
# (560, 25)
# {'1010010005BCC200', '10100100052D3D00', '1010010005BA1600', '10100100052AB200', '101001000872D000', '101001000854D700', '10100100087A6100'}

# %%
# select a t1 catid
cat_id_t1 = '101001000872D000'

# %%
# subset the candidates database
gdf_t1_sub = candidate_sites_t1_t2[ candidate_sites_t1_t2.catid_left == cat_id_t1]
cat_id_t2_list = gdf_t1_sub.catid_right.to_list()

# %%
import folium

# %%
style_kwds = {'fillOpacity': 0.2, 'opacity': 1}

# Map t2 imagery: TODO - check this head(1)??
m = vhr_gdf[ vhr_gdf.catid.isin(cat_id_t2_list)][rm_datetime_cols(vhr_gdf)].head(1).explore(color='yellow',style_kwds=style_kwds, name='VHR t2', legend=True, 
                                                                                           tiles='http://services.arcgisonline.com/ArcGIS/rest/services/Canvas/World_Light_Gray_Base/MapServer/tile/{z}/{y}/{x}', 
                                                                                            attr=' ')
m = vhr_gdf[ vhr_gdf.catid == cat_id_t1][rm_datetime_cols(vhr_gdf)].explore(m=m, color='orange',style_kwds=style_kwds, name='VHR t1')
m = gdf_t1_sub[rm_datetime_cols(gdf_t1_sub)].explore(m=m, color='red', style_kwds=style_kwds, name='candidate site(s)')
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73e4e8c1918bb9b8c75e9793b766e338 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73e4e8c1918bb9b8c75e9793b766e338&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73e4e8c1918bb9b8c75e9793b766e338 = L.map(
#                 &quot;map_73e4e8c1918bb9b8c75e9793b766e338&quot;,
#                 {
#                     center: [64.52139281900006, -165.40304565599996],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_73e4e8c1918bb9b8c75e9793b766e338);
#
#
#
#
#
#             var tile_layer_1fb6f47b2bdc916079b6224679d32c6d = L.tileLayer(
#                 &quot;http://services.arcgisonline.com/ArcGIS/rest/services/Canvas/World_Light_Gray_Base/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot; &quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_73e4e8c1918bb9b8c75e9793b766e338);
#
#
#             map_73e4e8c1918bb9b8c75e9793b766e338.fitBounds(
#                 [[64.45550536500008, -165.58349609899997], [64.58728027300003, -165.22259521299998]],
#                 {}
#             );
#
#
#         function geo_json_1391907f91a16339f9a8ea0d79de821b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;yellow&quot;, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 1, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_1391907f91a16339f9a8ea0d79de821b_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_1391907f91a16339f9a8ea0d79de821b_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_1391907f91a16339f9a8ea0d79de821b_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_1391907f91a16339f9a8ea0d79de821b_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_1391907f91a16339f9a8ea0d79de821b.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_1391907f91a16339f9a8ea0d79de821b_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_1391907f91a16339f9a8ea0d79de821b = L.geoJson(null, {
#                 onEachFeature: geo_json_1391907f91a16339f9a8ea0d79de821b_onEachFeature,
#
#                 style: geo_json_1391907f91a16339f9a8ea0d79de821b_styler,
#                 pointToLayer: geo_json_1391907f91a16339f9a8ea0d79de821b_pointToLayer
#         });

# %% [markdown]
# # Candidate sites + existing CNN CHM footprints + available VHR footprints
#
# For a given site, get the `VHR` imagery we should process to do a `change analysis`

# %%
candidate_sites_t1_t2 = gpd.read_file(f'{dir_prj_pmm}/data/arc/candidate_sites_t1t2_db.gpkg')
candidate_sites = gpd.read_file(os.path.join(MAINDIR, 'footprints','footprints_candidate_sites.gpkg'))

# %%
footprint_chm
# Out:
# '/explore/nobackup/projects/above/misc/ABoVE_Shrubs/footprints/footprints_20231014_chm.gpkg'

# %%
footprint_chm_gdf = gpd.read_file(footprint_chm)

# %%
footprint_chm_gdf.groupby(['sensor']).aggregate(n_obs_sensor = ('sensor', 'count')).reset_index()
# Out:
#   sensor  n_obs_sensor
# 0   WV02           672
# 1   WV03           274

# %% [markdown]
# ### Select CHM footprints intersectn cgandidate site
# `red` --> candidate site
# `black` --> CHMs we have that intersect cand site
# `orange` --> old VHR we need to process to CHM
# `yellow` --> new VHR we need to process to CHM

# %%
# Select CHMs that intersect site
footprint_chm_site_intersection = gdf_selection(footprint_chm_gdf, candidate_sites[candidate_sites.name == cand_site_name])

# %% [markdown]
# #### CatIDs processed to CHMs for this site

# %%
catids_chms_processed = footprint_site_intersection.catid.to_list()
print(len(catids_chms_processed))
footprint_site_intersection.year.to_list()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 catids_chms_processed = footprint_site_intersection.catid.to_list()
#       2 print(len(catids_chms_processed))
#       3 footprint_site_intersection.year.to_list()
#
# NameError: name 'footprint_site_intersection' is not defined

# %% [markdown]
# ### VHR data (old & new) available for this site

# %%
vhr_gdf_selection_old_intersection = gdf_selection(vhr_gdf_selection_old, candidate_sites[candidate_sites.name == cand_site_name])
vhr_gdf_selection_new_intersection = gdf_selection(vhr_gdf_selection_new, candidate_sites[candidate_sites.name == cand_site_name])

# %% [markdown]
# #### CatIDs available in archive to process to CHMs

# %%
catid_vhr_old = vhr_gdf_selection_old_intersection.catid.to_list()
print(len(catid_vhr_old))
vhr_gdf_selection_old_intersection.acq_year.to_list()
# Out:
# 7
# [2006, 2006, 2007, 2007, 2008, 2008, 2008]

# %%
catids_vhr_old_need = [x for x in catid_vhr_old if x not in catids_chms_processed]
len(catids_vhr_old_need)
# Out:
# 7

# %%
catids_vhr_new = vhr_gdf_selection_new_intersection.catid.to_list()
print(len(catids_vhr_new))
print(vhr_gdf_selection_new_intersection.acq_year.to_list())
# Out:
# 80
# [2018, 2018, 2018, 2018, 2018, 2018, 2018, 2019, 2019, 2019, 2020, 2020, 2020, 2020, 2020, 2020, 2021, 2021, 2021, 2021, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2018, 2018, 2018, 2018, 2018, 2018, 2020, 2020, 2020, 2020, 2020, 2021, 2021, 2021, 2021, 2021, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2019, 2019, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2021, 2021, 2021, 2021, 2021, 2021, 2022, 2022, 2022, 2022, 2022, 2022, 2022]

# %%
#set(catids_vhr_new) - set(catids_chms_processed)
catids_vhr_new_need = [x for x in catids_vhr_new if x not in catids_chms_processed]
len(catids_vhr_new_need)
# Out:
# 78

# %% [markdown]
# ### Map VHR we should process to be able to examine change
#
# **check for cloudcover**

# %%
style_kwds = {'fillOpacity': 0.2, 'opacity': 1}
m = footprint_chm_site_intersection.drop('date', axis=1).explore(color='black', style_kwds=style_kwds, name='CHMs processed')
m = vhr_gdf_selection_old_intersection[vhr_gdf_selection_old_intersection.catid.isin(catids_vhr_old_need)].drop(['min_added_date','max_added_date'], axis=1).explore(color='orange', name='VHR[old] need', style_kwds=style_kwds, m=m)
m = vhr_gdf_selection_new_intersection[vhr_gdf_selection_new_intersection.catid.isin(catids_vhr_new_need)].drop(['min_added_date','max_added_date'], axis=1).explore(color='yellow', name='VHR[new] need', style_kwds=style_kwds,m=m)
m = candidate_sites[candidate_sites.name == cand_site_name].explore(m=m, color='red')
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0989167304eba402fa996a6ec49d41df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0989167304eba402fa996a6ec49d41df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0989167304eba402fa996a6ec49d41df = L.map(
#                 &quot;map_0989167304eba402fa996a6ec49d41df&quot;,
#                 {
#                     center: [64.68844225072337, -165.32764335277488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0989167304eba402fa996a6ec49d41df);
#
#
#
#
#
#             var tile_layer_7b3cefbadbb35a48b75f1cab71593bf2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0989167304eba402fa996a6ec49d41df);
#
#
#             map_0989167304eba402fa996a6ec49d41df.fitBounds(
#                 [[64.30949039208566, -166.1147143101609], [65.06739410936108, -164.54057239538886]],
#                 {}
#             );
#
#
#         function geo_json_ab16ed14e4e2496233b9dca0fa366d22_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 1, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_ab16ed14e4e2496233b9dca0fa366d22_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_ab16ed14e4e2496233b9dca0fa366d22_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_ab16ed14e4e2496233b9dca0fa366d22_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_ab16ed14e4e2496233b9dca0fa366d22_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_ab16ed14e4e2496233b9dca0fa366d22.resetStyle(e.target);
#                     }
#                 },
#                 mouseover
